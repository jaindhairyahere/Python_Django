# %%
import numpy as np 
import pandas as pd
from bs4 import BeautifulSoup
import requests
import sqlite3
url1 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc"
url2 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=51&ref_=adv_nxt"
url3 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=101&ref_=adv_nxt"
url4 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=151&ref_=adv_nxt"
url5 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=201&ref_=adv_nxt"
    
urls = [url1, url2, url3, url4, url5]
titles = []
ratings = []
release_dates = []
descriptions = []
durations = []

# %%
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
    name_release_class = soup.find_all('h3', {'class': 'lister-item-header'})
    rating_class = soup.find_all('div',{'class':'ratings-bar'})
    desc_class = soup.find_all('p', {'class': 'text-muted'})
    time_class = soup.find_all('span',{'class':'runtime'})

    for name_release_objects in name_release_class:
        for name in name_release_objects.find_all('a'):
            titles.append(name.text)
        for release in name_release_objects.find_all('span',{'class':'lister-item-year text-muted unbold'}):
            release_dates.append(release.text)
    for rating_object in rating_class:
        for rating in rating_object.find_all('strong'):
            ratings.append(rating.text)
    for desc in desc_class:
        desc_text = desc.text.lstrip()
        descriptions.append(desc_text)
    for time in time_class:
        durations.append(time.text)

# %%
titles = np.array(titles)
ratings = np.array(ratings)
release_dates = np.array(release_dates)
descriptions = np.array(descriptions[1::2])

'''
    for time_objects in time_class:
        durations.append(duration.text)
'''
# Out:
# '\n    for time_objects in time_class:\n        durations.append(duration.text)\n'

# %%
my_db
# Out:
#                                              title rating release_date  \
# 0                         The Shawshank Redemption    9.3       (1994)
# 1                                    The Godfather    9.2       (1972)
# 2                                  The Dark Knight    9.0       (2008)
# 3                           The Godfather: Part II    9.0       (1974)
# 4    The Lord of the Rings: The Return of the King    8.9       (2003)
# ..                                             ...    ...          ...
# 245                                 Monsters, Inc.    8.0       (2001)
# 246                                        Aladdin    8.0       (1992)
# 247                         Tenkû no shiro Rapyuta    8.0       (1986)
# 248                                 The Terminator    8.0       (1984)
# 249             Butch Cassidy and the Sundance Kid    8.0       (1969)
#
#     duration                                        description
# 0    142 min  Two imprisoned men bond over a number of years...
# 1    175 min  The aging patriarch of an organized crime dyna...
# 2    152 min  When the menace known as the Joker wreaks havo...
# 3    202 min  The early life and career of Vito Corleone in ...
# 4    201 min  Gandalf and Aragorn lead the World of Men agai...
# ..       ...                                                ...
# 245   92 min  In order to power the city, monsters have to s...
# 246   90 min  A kindhearted street urchin and a power-hungry...
# 247  125 min  A young boy and a girl with a magic crystal mu...
# 248  107 min  A seemingly indestructible robot is sent from ...
# 249  110 min  Wyoming, early 1900s. Butch Cassidy and The Su...
#
# [250 rows x 5 columns]

# %%
import sqlite3 as db
conn = db.connect('db.sqlite3')
c = conn.cursor()
conn.commit()
my_db.to_sql('Movie',conn,if_exists='replace',index=False)
conn.commit()

# %%
my_db = pd.DataFrame()
my_db['title']= titles
my_db['rating']= ratings
my_db['release_date']= release_dates
my_db['duration']=durations

my_db['description']=descriptions

# %%
all_mo = list(zip(titles,ratings,release_dates,durations,descriptions))

# %%
pd.DataFrame(all_mo)
# Out:
#                                                  0    1       2        3  \
# 0                         The Shawshank Redemption  9.3  (1994)  142 min
# 1                                    The Godfather  9.2  (1972)  175 min
# 2                                  The Dark Knight  9.0  (2008)  152 min
# 3                           The Godfather: Part II  9.0  (1974)  202 min
# 4    The Lord of the Rings: The Return of the King  8.9  (2003)  201 min
# ..                                             ...  ...     ...      ...
# 245                                 Monsters, Inc.  8.0  (2001)   92 min
# 246                                        Aladdin  8.0  (1992)   90 min
# 247                         Tenkû no shiro Rapyuta  8.0  (1986)  125 min
# 248                                 The Terminator  8.0  (1984)  107 min
# 249             Butch Cassidy and the Sundance Kid  8.0  (1969)  110 min
#
#                                                      4
# 0    Two imprisoned men bond over a number of years...
# 1    The aging patriarch of an organized crime dyna...
# 2    When the menace known as the Joker wreaks havo...
# 3    The early life and career of Vito Corleone in ...
# 4    Gandalf and Aragorn lead the World of Men agai...
# ..                                                 ...
# 245  In order to power the city, monsters have to s...
# 246  A kindhearted street urchin and a power-hungry...
# 247  A young boy and a girl with a magic crystal mu...
# 248  A seemingly indestructible robot is sent from ...
# 249  Wyoming, early 1900s. Butch Cassidy and The Su...
#
# [250 rows x 5 columns]

# %%
print(all_mo)
# Out:
# [('The Shawshank Redemption', '9.3', '(1994)', '142 min', 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.'), ('The Godfather', '9.2', '(1972)', '175 min', 'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.'), ('The Dark Knight', '9.0', '(2008)', '152 min', 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.'), ('The Godfather: Part II', '9.0', '(1974)', '202 min', 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.'), ('The Lord of the Rings: The Return of the King', '8.9', '(2003)', '201 min', "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring."), ('Pulp Fiction', '8.9', '(1994)', '154 min', 'The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.'), ("Schindler's List", '8.9', '(1993)', '195 min', 'In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.'), ('12 Angry Men', '8.9', '(1957)', '96 min', 'A jury holdout attempts to prevent a miscarriage of justice by forcing his colleagues to reconsider the evidence.'), ('Joker', '8.8', '(I) (2019)', '122 min', 'In Gotham City, mentally-troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: "The Joker".'), ('Inception', '8.8', '(2010)', '148 min', 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O.'), ('Fight Club', '8.8', '(1999)', '139 min', 'An insomniac office worker and a devil-may-care soapmaker form an underground fight club that evolves into something much, much more.'), ('The Lord of the Rings: The Fellowship of the Ring', '8.8', '(2001)', '178 min', 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.'), ('Forrest Gump', '8.8', '(1994)', '142 min', 'The presidencies of Kennedy and Johnson, the events of Vietnam, Watergate, and other history unfold through the perspective of an Alabama man with an IQ of 75.'), ('Il buono, il brutto, il cattivo', '8.8', '(1966)', '161 min', 'A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.'), ('The Lord of the Rings: The Two Towers', '8.7', '(2002)', '179 min', "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard."), ('The Matrix', '8.7', '(1999)', '136 min', 'A computer hacker learns from mysterious rebels about the true nature of his reality and his role in the war against its controllers.'), ('Goodfellas', '8.7', '(1990)', '146 min', 'The story of Henry Hill and his life in the mob, covering his relationship with his wife Karen Hill and his mob partners Jimmy Conway and Tommy DeVito in the Italian-American crime syndicate.'), ('Star Wars: Episode V - The Empire Strikes Back', '8.7', '(1980)', '124 min', 'After the Rebels are brutally overpowered by the Empire on the ice planet Hoth, Luke Skywalker begins Jedi training with Yoda, while his friends are pursued by Darth Vader.'), ("One Flew Over the Cuckoo's Nest", '8.7', '(1975)', '133 min', 'A criminal pleads insanity and is admitted to a mental institu ...

# %%
import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE',	'RESTapi.settings')

import django
django.setup()


if __name__ == "__main__":

    from bs4 import BeautifulSoup
    import requests
    import numpy as np 
    import pandas as pd
    from bs4 import BeautifulSoup
    import requests
    import sqlite3
    import sqlite3 as db
    from quantify_capital_assignment.models import Movie

    url1 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc"
    url2 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=51&ref_=adv_nxt"
    url3 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=101&ref_=adv_nxt"
    url4 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=151&ref_=adv_nxt"
    url5 = "https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=201&ref_=adv_nxt"
    urls = [url1, url2, url3, url4, url5]

    title = []
    rating = []
    release_date = []
    description = []
    duration = []

    for url in urls:
        response = requests.get(url)

        soup = BeautifulSoup(response.text, features='html.parser')
        name_release_class = soup.find_all('h3', {'class': 'lister-item-header'})
        rating_class = soup.find_all('div',{'class':'ratings-bar'})
        desc_class = soup.find_all('p', {'class': 'text-muted'})
        time_class = soup.find_all('span',{'class':'runtime'})

        for name_release_objects in name_release_class:
            for name in name_release_objects.find_all('a'):
                title.append(name.text)
            for release in name_release_objects.find_all('span',{'class':'lister-item-year text-muted unbold'}):
                release_date.append(release.text)
        for rating_object in rating_class:
            for rating in rating_object.find_all('strong'):
                rating.append(rating.text)
        for desc in desc_class:
            desc_text = desc.text.lstrip()
            description.append(desc_text)
        for time in time_class:
            duration.append(time.text)

    title = np.array(title)
    rating = np.array(rating)
    release_date = np.array(release_date)
    description = np.array(description[1::2])
    
    # allMovies = list(zip(title, rating, release_date, description, duration))
    # for MovieObject in allMovies:
    #     Movie.objects.get_or_create(title=MovieObject[0], rating=MovieObject[1], release_date=MovieObject[2],description=MovieObject[3], duration=MovieObject[4])
    # print(pd.DataFrame(allMovies))
   
    print(len(rating))
    my_db = pd.DataFrame()
    my_db['title']= title
    my_db['rating']= 8 * len(rating)
    my_db['rating']= rating
    my_db['release_date']= release_date
    my_db['duration'] = duration
    my_db['description']=description
    my_db['id']=[i for i in range(1,251)]
    conn = db.connect('db.sqlite3')
    c = conn.cursor()
    conn.commit()
    my_db.to_sql('quantify_capital_assignment_movie',conn,if_exists='replace',index=False)
    conn.commit()        
    conn.close()    
    print("Successfully Populated the Model")
